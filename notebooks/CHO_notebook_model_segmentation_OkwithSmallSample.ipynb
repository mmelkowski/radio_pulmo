# %%
#https://www.kaggle.com/code/nikhilpandey360/lung-segmentation-from-chest-x-ray-datasetb

# %%
import numpy as np 
import tensorflow as tf
import pandas as pd
#from tqdm import tqdm
import os
from cv2 import imread, createCLAHE 
import cv2
from glob import glob
# %matplotlib inline
import matplotlib.pyplot as plt


path_to_data = r"C:\Users\Inrae\Documents\Projet_Data_Science"
data_folder_path = os.path.join(path_to_data,"COVID-19_Radiography_Dataset")

cat="Normal"
image_path = os.path.join(data_folder_path,cat,"images")
mask_path = os.path.join(data_folder_path,cat,"masks")
# image_path = os.path.join("../input/data/Lung Segmentation/CXR_png")
# mask_path = os.path.join("../input/data/Lung Segmentation/","masks/")

# %%
# we have 704 masks but 800 images. Hence we are going to
# make a 1-1 correspondance from mask to images, not the usual other way.
images = os.listdir(image_path)
mask = os.listdir(mask_path)

# %%
#perform sanity check

def plotMask(X,y):
    sample = []
    
    for i in range(6):
        left = X[i]
        right = y[i]
        combined = np.hstack((left,right))
        sample.append(combined)
        
        
    for i in range(0,6,3):

        plt.figure(figsize=(25,10))
        
        plt.subplot(2,3,1+i)
        plt.imshow(sample[i])
        
        plt.subplot(2,3,2+i)
        plt.imshow(sample[i+1])
        
        
        plt.subplot(2,3,3+i)
        plt.imshow(sample[i+2])
        
        plt.show()

# %%
import random

testing_files = os.listdir(image_path)
val_samples = 2000
random.Random(1337).shuffle(testing_files)
testing_files = testing_files[:-val_samples]
training_files = testing_files[:-val_samples]

#testing_files = set(os.listdir(image_path)) & set(os.listdir(mask_path))
#training_files = check

def getData(X_shape, flag = "test"):
    im_array = []
    mask_array = []
    
    if flag == "test":
        for i in testing_files: 
            im = cv2.resize(cv2.imread(os.path.join(image_path,i)),(X_shape,X_shape))[:,:,0]
            mask = cv2.resize(cv2.imread(os.path.join(mask_path,i)),(X_shape,X_shape))[:,:,0]
            
            im_array.append(im)
            mask_array.append(mask)
        
        return im_array,mask_array
    
    if flag == "train":
        for i in training_files: 
            im = cv2.resize(cv2.imread(os.path.join(image_path,i)),(X_shape,X_shape))[:,:,0]
            mask = cv2.resize(cv2.imread(os.path.join(mask_path,i)),(X_shape,X_shape))[:,:,0]

            im_array.append(im)
            mask_array.append(mask)

        return im_array,mask_array

# %%
# Load training and testing data
dim = 256
X_train,y_train = getData(dim,flag="train")
X_test, y_test = getData(dim)

X_train = np.array(X_train).reshape(len(X_train),dim,dim,1)
y_train = np.array(y_train).reshape(len(y_train),dim,dim,1)
X_test = np.array(X_test).reshape(len(X_test),dim,dim,1)
y_test = np.array(y_test).reshape(len(y_test),dim,dim,1)
assert X_train.shape == y_train.shape
assert X_test.shape == y_test.shape
images = np.concatenate((X_train,X_test),axis=0)
mask  = np.concatenate((y_train,y_test),axis=0)

# %%
print("training set")
plotMask(X_train,y_train)
print("testing set")
plotMask(X_test,y_test)
# Out:
# training set
# testing set

# %%
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras import backend as keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler


def dice_coef(y_true, y_pred):
    y_true_f = keras.flatten(y_true)
    y_pred_f = keras.flatten(y_pred)
    intersection = keras.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (keras.sum(y_true_f) + keras.sum(y_pred_f) + 1)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def unet(input_size=(dim,dim,1)):
    inputs = Input(input_size)
    
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

    return Model(inputs=[inputs], outputs=[conv10])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
weight_path="{}_weights.best.hdf5".format('cxr_reg')

checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, 
                             save_best_only=True, mode='min', save_weights_only = True)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.5, 
                                   patience=3, 
                                   verbose=1, mode='min', min_delta=0.0001, cooldown=2, min_lr=1e-6)
early = EarlyStopping(monitor="val_loss", 
                      mode="min", 
                      patience=15) # probably needs to be more patient, but kaggle time is limited
callbacks_list = [checkpoint, early, reduceLROnPlat]

# %%
model = unet(input_size=(256,256,1))
model.compile(optimizer=Adam(lr=0.0001), loss=dice_coef_loss,
                  metrics=[dice_coef, 'binary_accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 32  320         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 32  9248        ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 32  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 64  18496       ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 64  36928       ['conv2d_2[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 64)  0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 128)  147584      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 128)  0          ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 256)  590080      ['conv2d_6[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 256)  0          ['conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 512)  1180160     ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 512)  2359808     ['conv2d_8[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 256)  524544     ['conv2d_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 32, 32, 512)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 256)  1179904     ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 256)  590080      ['conv2d_10[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 128)  131200     ['conv2d_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 256)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 128)  295040      ['concatenate_1[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 128)  147584      ['conv2d_12[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 64  32832      ['conv2d_13[0][0]']
#  spose)                         )
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_transpose_2[0][0]',
#                                 8)                                'conv2d_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 64  36928       ['conv2d_14[0][0]']
#                                 )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 32  8224       ['conv2d_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 64  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 32  18464       ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 256, 256, 32  9248        ['conv2d_16[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 1)  33          ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 7,759,521
# Trainable params: 7,759,521
# Non-trainable params: 0
# __________________________________________________________________________________________________
# c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
del loss_history
import gc
gc.collect()
tf.keras.backend.clear_session()


from IPython.display import clear_output
from tensorflow.keras.optimizers import Adam 
from sklearn.model_selection import train_test_split


train_vol, validation_vol, train_seg, validation_seg = train_test_split((images[:600]-127)/127, 
                                                             (mask[:600]>127).astype(np.float32),
                                                             test_size = 0.1,random_state = 2018)

train_vol, test_vol, train_seg, test_seg = train_test_split(train_vol,train_seg, 
                                                            test_size = 0.1, 
                                                            random_state = 2018)


loss_history = model.fit(x = train_vol,
                       y = train_seg,
                         batch_size = 8,
                  epochs = 50,
                  validation_data =(test_vol,test_seg) ,
                  callbacks=callbacks_list)
# Out:
# Epoch 1/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9453 - dice_coef: 0.9452 - binary_accuracy: 0.9729
# Epoch 1: val_loss improved from -0.58580 to -0.94214, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 17s 271ms/step - loss: -0.9453 - dice_coef: 0.9452 - binary_accuracy: 0.9729 - val_loss: -0.9421 - val_dice_coef: 0.9425 - val_binary_accuracy: 0.9696 - lr: 6.2500e-06
# Epoch 2/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9465 - dice_coef: 0.9466 - binary_accuracy: 0.9734
# Epoch 2: val_loss improved from -0.94214 to -0.94256, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 228ms/step - loss: -0.9465 - dice_coef: 0.9466 - binary_accuracy: 0.9734 - val_loss: -0.9426 - val_dice_coef: 0.9428 - val_binary_accuracy: 0.9702 - lr: 6.2500e-06
# Epoch 3/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9470 - dice_coef: 0.9469 - binary_accuracy: 0.9737
# Epoch 3: val_loss improved from -0.94256 to -0.94350, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 229ms/step - loss: -0.9470 - dice_coef: 0.9469 - binary_accuracy: 0.9737 - val_loss: -0.9435 - val_dice_coef: 0.9438 - val_binary_accuracy: 0.9707 - lr: 6.2500e-06
# Epoch 4/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9475 - dice_coef: 0.9475 - binary_accuracy: 0.9739
# Epoch 4: val_loss did not improve from -0.94350
# 61/61 [==============================] - 14s 232ms/step - loss: -0.9475 - dice_coef: 0.9475 - binary_accuracy: 0.9739 - val_loss: -0.9432 - val_dice_coef: 0.9435 - val_binary_accuracy: 0.9705 - lr: 6.2500e-06
# Epoch 5/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9484 - dice_coef: 0.9482 - binary_accuracy: 0.9745
# Epoch 5: val_loss improved from -0.94350 to -0.94432, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 225ms/step - loss: -0.9484 - dice_coef: 0.9482 - binary_accuracy: 0.9745 - val_loss: -0.9443 - val_dice_coef: 0.9446 - val_binary_accuracy: 0.9710 - lr: 6.2500e-06
# Epoch 6/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9491 - dice_coef: 0.9491 - binary_accuracy: 0.9748
# Epoch 6: val_loss improved from -0.94432 to -0.94434, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 232ms/step - loss: -0.9491 - dice_coef: 0.9491 - binary_accuracy: 0.9748 - val_loss: -0.9443 - val_dice_coef: 0.9447 - val_binary_accuracy: 0.9708 - lr: 6.2500e-06
# Epoch 7/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9500 - dice_coef: 0.9498 - binary_accuracy: 0.9753
# Epoch 7: val_loss improved from -0.94434 to -0.94439, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 233ms/step - loss: -0.9500 - dice_coef: 0.9498 - binary_accuracy: 0.9753 - val_loss: -0.9444 - val_dice_coef: 0.9448 - val_binary_accuracy: 0.9708 - lr: 6.2500e-06
# Epoch 8/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9507 - dice_coef: 0.9507 - binary_accuracy: 0.9756
# Epoch 8: val_loss improved from -0.94439 to -0.94521, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 233ms/step - loss: -0.9507 - dice_coef: 0.9507 - binary_accuracy: 0.9756 - val_loss: -0.9452 - val_dice_coef: 0.9455 - val_binary_accuracy: 0.9715 - lr: 6.2500e-06
# Epoch 9/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9511 - dice_coef: 0.9511 - binary_accuracy: 0.9759
# Epoch 9: val_loss did not improve from -0.94521
# 61/61 [==============================] - 14s 234ms/step - loss: -0.9511 - dice_coef: 0.9511 - binary_accuracy: 0.9759 - val_loss: -0.9451 - val_dice_coef: 0.9454 - val_binary_accuracy: 0.9714 - lr: 6.2500e-06
# Epoch 10/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9515 - dice_coef: 0.9515 - binary_accuracy: 0.9759
# Epoch 10: val_loss improved from -0.94521 to -0.94562, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 232ms/step - loss: -0.9515 - dice_coef: 0.9515 - binary_accuracy: 0.9759 - val_loss: -0.9456 - val_dice_coef: 0.9460 - val_binary_accuracy: 0.9717 - lr: 6.2500e-06
# Epoch 11/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9521 - dice_coef: 0.9522 - binary_accuracy: 0.9763
# Epoch 11: val_loss improved from -0.94562 to -0.94580, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 232ms/step - loss: -0.9521 - dice_coef: 0.9522 - binary_accuracy: 0.9763 - val_loss: -0.9458 - val_dice_coef: 0.9462 - val_binary_accuracy: 0.9717 - lr: 6.2500e-06
# Epoch 12/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9531 - dice_coef: 0.9531 - binary_accuracy: 0.9768
# Epoch 12: val_loss improved from -0.94580 to -0.94618, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 235ms/step - loss: -0.9531 - dice_coef: 0.9531 - binary_accuracy: 0.9768 - val_loss: -0.9462 - val_dice_coef: 0.9465 - val_binary_accuracy: 0.9721 - lr: 6.2500e-06
# Epoch 13/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9536 - dice_coef: 0.9536 - binary_accuracy: 0.9771
# Epoch 13: val_loss improved from -0.94618 to -0.94671, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 223ms/step - loss: -0.9536 - dice_coef: 0.9536 - binary_accuracy: 0.9771 - val_loss: -0.9467 - val_dice_coef: 0.9471 - val_binary_accuracy: 0.9720 - lr: 6.2500e-06
# Epoch 14/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9538 - dice_coef: 0.9538 - binary_accuracy: 0.9772
# Epoch 14: val_loss improved from -0.94671 to -0.94673, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 224ms/step - loss: -0.9538 - dice_coef: 0.9538 - binary_accuracy: 0.9772 - val_loss: -0.9467 - val_dice_coef: 0.9471 - val_binary_accuracy: 0.9720 - lr: 6.2500e-06
# Epoch 15/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9548 - dice_coef: 0.9547 - binary_accuracy: 0.9775
# Epoch 15: val_loss improved from -0.94673 to -0.94692, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 227ms/step - loss: -0.9548 - dice_coef: 0.9547 - binary_accuracy: 0.9775 - val_loss: -0.9469 - val_dice_coef: 0.9473 - val_binary_accuracy: 0.9722 - lr: 6.2500e-06
# Epoch 16/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9552 - dice_coef: 0.9551 - binary_accuracy: 0.9779
# Epoch 16: val_loss improved from -0.94692 to -0.94737, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 229ms/step - loss: -0.9552 - dice_coef: 0.9551 - binary_accuracy: 0.9779 - val_loss: -0.9474 - val_dice_coef: 0.9477 - val_binary_accuracy: 0.9726 - lr: 6.2500e-06
# Epoch 17/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9561 - dice_coef: 0.9561 - binary_accuracy: 0.9782
# Epoch 17: val_loss improved from -0.94737 to -0.94738, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 228ms/step - loss: -0.9561 - dice_coef: 0.9561 - binary_accuracy: 0.9782 - val_loss: -0.9474 - val_dice_coef: 0.9478 - val_binary_accuracy: 0.9724 - lr: 6.2500e-06
# Epoch 18/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9566 - dice_coef: 0.9566 - binary_accuracy: 0.9784
# Epoch 18: val_loss improved from -0.94738 to -0.94756, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 223ms/step - loss: -0.9566 - dice_coef: 0.9566 - binary_accuracy: 0.9784 - val_loss: -0.9476 - val_dice_coef: 0.9479 - val_binary_accuracy: 0.9728 - lr: 6.2500e-06
# Epoch 19/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9570 - dice_coef: 0.9569 - binary_accuracy: 0.9786
# Epoch 19: val_loss improved from -0.94756 to -0.94857, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 223ms/step - loss: -0.9570 - dice_coef: 0.9569 - binary_accuracy: 0.9786 - val_loss: -0.9486 - val_dice_coef: 0.9490 - val_binary_accuracy: 0.9732 - lr: 6.2500e-06
# Epoch 20/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9574 - dice_coef: 0.9574 - binary_accuracy: 0.9789
# Epoch 20: val_loss improved from -0.94857 to -0.94874, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 13s 219ms/step - loss: -0.9574 - dice_coef: 0.9574 - binary_accuracy: 0.9789 - val_loss: -0.9487 - val_dice_coef: 0.9491 - val_binary_accuracy: 0.9733 - lr: 6.2500e-06
# Epoch 21/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9584 - dice_coef: 0.9584 - binary_accuracy: 0.9794
# Epoch 21: val_loss improved from -0.94874 to -0.94907, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 224ms/step - loss: -0.9584 - dice_coef: 0.9584 - binary_accuracy: 0.9794 - val_loss: -0.9491 - val_dice_coef: 0.9495 - val_binary_accuracy: 0.9734 - lr: 6.2500e-06
# Epoch 22/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9586 - dice_coef: 0.9586 - binary_accuracy: 0.9795
# Epoch 22: val_loss did not improve from -0.94907
# 61/61 [==============================] - 14s 228ms/step - loss: -0.9586 - dice_coef: 0.9586 - binary_accuracy: 0.9795 - val_loss: -0.9488 - val_dice_coef: 0.9492 - val_binary_accuracy: 0.9732 - lr: 6.2500e-06
# Epoch 23/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9592 - dice_coef: 0.9592 - binary_accuracy: 0.9798
# Epoch 23: val_loss improved from -0.94907 to -0.94922, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 226ms/step - loss: -0.9592 - dice_coef: 0.9592 - binary_accuracy: 0.9798 - val_loss: -0.9492 - val_dice_coef: 0.9496 - val_binary_accuracy: 0.9737 - lr: 6.2500e-06
# Epoch 24/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9594 - dice_coef: 0.9593 - binary_accuracy: 0.9799
# Epoch 24: val_loss did not improve from -0.94922
# 61/61 [==============================] - 14s 226ms/step - loss: -0.9594 - dice_coef: 0.9593 - binary_accuracy: 0.9799 - val_loss: -0.9490 - val_dice_coef: 0.9494 - val_binary_accuracy: 0.9736 - lr: 6.2500e-06
# Epoch 25/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9599 - dice_coef: 0.9599 - binary_accuracy: 0.9802
# Epoch 25: val_loss improved from -0.94922 to -0.94987, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 223ms/step - loss: -0.9599 - dice_coef: 0.9599 - binary_accuracy: 0.9802 - val_loss: -0.9499 - val_dice_coef: 0.9503 - val_binary_accuracy: 0.9737 - lr: 6.2500e-06
# Epoch 26/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9607 - dice_coef: 0.9607 - binary_accuracy: 0.9806
# Epoch 26: val_loss improved from -0.94987 to -0.95072, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 13s 221ms/step - loss: -0.9607 - dice_coef: 0.9607 - binary_accuracy: 0.9806 - val_loss: -0.9507 - val_dice_coef: 0.9511 - val_binary_accuracy: 0.9743 - lr: 6.2500e-06
# Epoch 27/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9607 - dice_coef: 0.9606 - binary_accuracy: 0.9806
# Epoch 27: val_loss improved from -0.95072 to -0.95073, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 223ms/step - loss: -0.9607 - dice_coef: 0.9606 - binary_accuracy: 0.9806 - val_loss: -0.9507 - val_dice_coef: 0.9512 - val_binary_accuracy: 0.9742 - lr: 6.2500e-06
# Epoch 28/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9616 - dice_coef: 0.9616 - binary_accuracy: 0.9809
# Epoch 28: val_loss did not improve from -0.95073
# 61/61 [==============================] - 14s 227ms/step - loss: -0.9616 - dice_coef: 0.9616 - binary_accuracy: 0.9809 - val_loss: -0.9497 - val_dice_coef: 0.9502 - val_binary_accuracy: 0.9734 - lr: 6.2500e-06
# Epoch 29/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9617 - dice_coef: 0.9618 - binary_accuracy: 0.9810
# Epoch 29: val_loss improved from -0.95073 to -0.95148, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 225ms/step - loss: -0.9617 - dice_coef: 0.9618 - binary_accuracy: 0.9810 - val_loss: -0.9515 - val_dice_coef: 0.9519 - val_binary_accuracy: 0.9747 - lr: 6.2500e-06
# Epoch 30/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9622 - dice_coef: 0.9622 - binary_accuracy: 0.9812
# Epoch 30: val_loss improved from -0.95148 to -0.95200, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 228ms/step - loss: -0.9622 - dice_coef: 0.9622 - binary_accuracy: 0.9812 - val_loss: -0.9520 - val_dice_coef: 0.9524 - val_binary_accuracy: 0.9749 - lr: 6.2500e-06
# Epoch 31/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9630 - dice_coef: 0.9629 - binary_accuracy: 0.9816
# Epoch 31: val_loss did not improve from -0.95200
# 61/61 [==============================] - 14s 228ms/step - loss: -0.9630 - dice_coef: 0.9629 - binary_accuracy: 0.9816 - val_loss: -0.9519 - val_dice_coef: 0.9524 - val_binary_accuracy: 0.9748 - lr: 6.2500e-06
# Epoch 32/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9635 - dice_coef: 0.9635 - binary_accuracy: 0.9819
# Epoch 32: val_loss did not improve from -0.95200
# 61/61 [==============================] - 13s 219ms/step - loss: -0.9635 - dice_coef: 0.9635 - binary_accuracy: 0.9819 - val_loss: -0.9518 - val_dice_coef: 0.9522 - val_binary_accuracy: 0.9750 - lr: 6.2500e-06
# Epoch 33/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9631 - dice_coef: 0.9632 - binary_accuracy: 0.9818
# Epoch 33: val_loss improved from -0.95200 to -0.95226, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 226ms/step - loss: -0.9631 - dice_coef: 0.9632 - binary_accuracy: 0.9818 - val_loss: -0.9523 - val_dice_coef: 0.9527 - val_binary_accuracy: 0.9751 - lr: 6.2500e-06
# Epoch 34/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9639 - dice_coef: 0.9640 - binary_accuracy: 0.9821
# Epoch 34: val_loss did not improve from -0.95226
# 61/61 [==============================] - 14s 225ms/step - loss: -0.9639 - dice_coef: 0.9640 - binary_accuracy: 0.9821 - val_loss: -0.9518 - val_dice_coef: 0.9523 - val_binary_accuracy: 0.9749 - lr: 6.2500e-06
# Epoch 35/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9644 - dice_coef: 0.9644 - binary_accuracy: 0.9823
# Epoch 35: val_loss did not improve from -0.95226
# 61/61 [==============================] - 13s 220ms/step - loss: -0.9644 - dice_coef: 0.9644 - binary_accuracy: 0.9823 - val_loss: -0.9517 - val_dice_coef: 0.9522 - val_binary_accuracy: 0.9750 - lr: 6.2500e-06
# Epoch 36/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9643 - dice_coef: 0.9644 - binary_accuracy: 0.9823
# Epoch 36: val_loss improved from -0.95226 to -0.95270, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 226ms/step - loss: -0.9643 - dice_coef: 0.9644 - binary_accuracy: 0.9823 - val_loss: -0.9527 - val_dice_coef: 0.9532 - val_binary_accuracy: 0.9752 - lr: 6.2500e-06
# Epoch 37/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9652 - dice_coef: 0.9652 - binary_accuracy: 0.9827
# Epoch 37: val_loss improved from -0.95270 to -0.95304, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 230ms/step - loss: -0.9652 - dice_coef: 0.9652 - binary_accuracy: 0.9827 - val_loss: -0.9530 - val_dice_coef: 0.9535 - val_binary_accuracy: 0.9756 - lr: 6.2500e-06
# Epoch 38/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9653 - dice_coef: 0.9652 - binary_accuracy: 0.9828
# Epoch 38: val_loss improved from -0.95304 to -0.95368, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 229ms/step - loss: -0.9653 - dice_coef: 0.9652 - binary_accuracy: 0.9828 - val_loss: -0.9537 - val_dice_coef: 0.9542 - val_binary_accuracy: 0.9757 - lr: 6.2500e-06
# Epoch 39/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9657 - dice_coef: 0.9657 - binary_accuracy: 0.9830
# Epoch 39: val_loss did not improve from -0.95368
# 61/61 [==============================] - 14s 228ms/step - loss: -0.9657 - dice_coef: 0.9657 - binary_accuracy: 0.9830 - val_loss: -0.9535 - val_dice_coef: 0.9540 - val_binary_accuracy: 0.9756 - lr: 6.2500e-06
# Epoch 40/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9664 - dice_coef: 0.9665 - binary_accuracy: 0.9833
# Epoch 40: val_loss did not improve from -0.95368
# 61/61 [==============================] - 13s 220ms/step - loss: -0.9664 - dice_coef: 0.9665 - binary_accuracy: 0.9833 - val_loss: -0.9537 - val_dice_coef: 0.9542 - val_binary_accuracy: 0.9757 - lr: 6.2500e-06
# Epoch 41/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9665 - dice_coef: 0.9665 - binary_accuracy: 0.9834
# Epoch 41: val_loss improved from -0.95368 to -0.95380, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 226ms/step - loss: -0.9665 - dice_coef: 0.9665 - binary_accuracy: 0.9834 - val_loss: -0.9538 - val_dice_coef: 0.9543 - val_binary_accuracy: 0.9758 - lr: 6.2500e-06
# Epoch 42/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9669 - dice_coef: 0.9670 - binary_accuracy: 0.9836
# Epoch 42: val_loss improved from -0.95380 to -0.95423, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 230ms/step - loss: -0.9669 - dice_coef: 0.9670 - binary_accuracy: 0.9836 - val_loss: -0.9542 - val_dice_coef: 0.9547 - val_binary_accuracy: 0.9761 - lr: 6.2500e-06
# Epoch 43/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9673 - dice_coef: 0.9674 - binary_accuracy: 0.9839
# Epoch 43: val_loss did not improve from -0.95423
# 61/61 [==============================] - 14s 225ms/step - loss: -0.9673 - dice_coef: 0.9674 - binary_accuracy: 0.9839 - val_loss: -0.9538 - val_dice_coef: 0.9543 - val_binary_accuracy: 0.9760 - lr: 6.2500e-06
# Epoch 44/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9670 - dice_coef: 0.9671 - binary_accuracy: 0.9836
# Epoch 44: val_loss improved from -0.95423 to -0.95444, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 231ms/step - loss: -0.9670 - dice_coef: 0.9671 - binary_accuracy: 0.9836 - val_loss: -0.9544 - val_dice_coef: 0.9549 - val_binary_accuracy: 0.9761 - lr: 6.2500e-06
# Epoch 45/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9681 - dice_coef: 0.9682 - binary_accuracy: 0.9842
# Epoch 45: val_loss did not improve from -0.95444
# 61/61 [==============================] - 14s 226ms/step - loss: -0.9681 - dice_coef: 0.9682 - binary_accuracy: 0.9842 - val_loss: -0.9540 - val_dice_coef: 0.9546 - val_binary_accuracy: 0.9761 - lr: 6.2500e-06
# Epoch 46/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9686 - dice_coef: 0.9686 - binary_accuracy: 0.9844
# Epoch 46: val_loss improved from -0.95444 to -0.95510, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 224ms/step - loss: -0.9686 - dice_coef: 0.9686 - binary_accuracy: 0.9844 - val_loss: -0.9551 - val_dice_coef: 0.9556 - val_binary_accuracy: 0.9766 - lr: 6.2500e-06
# Epoch 47/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9688 - dice_coef: 0.9688 - binary_accuracy: 0.9845
# Epoch 47: val_loss did not improve from -0.95510
# 61/61 [==============================] - 14s 227ms/step - loss: -0.9688 - dice_coef: 0.9688 - binary_accuracy: 0.9845 - val_loss: -0.9544 - val_dice_coef: 0.9549 - val_binary_accuracy: 0.9761 - lr: 6.2500e-06
# Epoch 48/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9692 - dice_coef: 0.9692 - binary_accuracy: 0.9847
# Epoch 48: val_loss did not improve from -0.95510
# 61/61 [==============================] - 14s 224ms/step - loss: -0.9692 - dice_coef: 0.9692 - binary_accuracy: 0.9847 - val_loss: -0.9526 - val_dice_coef: 0.9531 - val_binary_accuracy: 0.9755 - lr: 6.2500e-06
# Epoch 49/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9691 - dice_coef: 0.9691 - binary_accuracy: 0.9847
# Epoch 49: val_loss improved from -0.95510 to -0.95561, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 225ms/step - loss: -0.9691 - dice_coef: 0.9691 - binary_accuracy: 0.9847 - val_loss: -0.9556 - val_dice_coef: 0.9561 - val_binary_accuracy: 0.9767 - lr: 6.2500e-06
# Epoch 50/50
# 61/61 [==============================] - ETA: 0s - loss: -0.9699 - dice_coef: 0.9699 - binary_accuracy: 0.9851
# Epoch 50: val_loss improved from -0.95561 to -0.95578, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 225ms/step - loss: -0.9699 - dice_coef: 0.9699 - binary_accuracy: 0.9851 - val_loss: -0.9558 - val_dice_coef: 0.9563 - val_binary_accuracy: 0.9769 - lr: 6.2500e-06

# %%
np.max(mask[1])
# Out:
# 255

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (10, 5))
ax1.plot(loss_history.history['loss'], '-', label = 'Loss')
ax1.plot(loss_history.history['val_loss'], '-', label = 'Validation Loss')
ax1.legend()

ax2.plot(100*np.array(loss_history.history['binary_accuracy']), '-', 
         label = 'Accuracy')
ax2.plot(100*np.array(loss_history.history['val_binary_accuracy']), '-',
         label = 'Validation Accuracy')
ax2.legend()

# %%
validation_vol = validation_vol[:30]

pred_candidates = np.random.randint(1,validation_vol.shape[0],10)
preds = model.predict(validation_vol)

plt.figure(figsize=(20,10))

for i in range(0,9,3):
    plt.subplot(3,3,i+1)
    
    plt.imshow(np.squeeze(validation_vol[pred_candidates[i]]))
    plt.xlabel("Base Image")
    
    
    plt.subplot(3,3,i+2)
    plt.imshow(np.squeeze(validation_seg[pred_candidates[i]]))
    plt.xlabel("Mask")
    
    plt.subplot(3,3,i+3)
    plt.imshow(np.squeeze(preds[pred_candidates[i]]))
    plt.xlabel("Prediction")
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[56], line 4
#       1 validation_vol = validation_vol[:30]
#       3 pred_candidates = np.random.randint(1,validation_vol.shape[0],10)
# ----> 4 preds = model.predict(validation_vol)
#       6 plt.figure(figsize=(20,10))
#       8 for i in range(0,9,3):
#
# File c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node 'model/concatenate_3/concat' defined at (most recent call last):
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#       app.launch_new_instance()
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#       app.start()
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#       self.io_loop.start()
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#       self.asyncio_loop.run_forever()
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\asyncio\base_events.py", line 603, in run_forever
#       self._run_once()
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\asyncio\base_events.py", line 1909, in _run_once
#       handle._run()
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#       await self.process_one()
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#       await dispatch(*args)
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#       await result
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#       await super().execute_request(stream, ident, parent)
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#       reply_content = await reply_content
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#       res = shell.run_cell(
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#       result = self._run_cell(
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#       result = runner(coro)
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#       coro.send(None)
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\Inrae\AppData\Local\Temp\ipykernel_7184\2704638823.py", line 2, in <module>
#       preds = model.predict(validation_vol)
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\keras\utils\traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\keras\engine\training.py", line 1982, in predict
#       tmp_batch_outputs = self.predict_function(iterator)
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\keras\engine\training.py", line 1801, in predict_function
#       return step_function(self, iterator)
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\keras\engine\training.py", line 1790, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\keras\engine\training.py", line 1783, in run_step
#       outputs = model.predict_step(data)
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\keras\engine\training.py", line 1751, in predict_step
#       return self(x, training=False)
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\keras\utils\traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\keras\engine\base_layer.py", line 1096, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\keras\utils\traceback_utils.py", line 92, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\keras\engine\functional.py", line 451, in call
#       return self._run_internal_graph(
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\keras\engine\functional.py", line 589, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\keras\utils\traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\keras\engine\base_layer.py", line 1096, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\keras\utils\traceback_utils.py", line 92, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\keras\layers\merge.py", line 183, in call
#       return self._merge_function(inputs)
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\keras\layers\merge.py", line 531, in _merge_function
#       return backend.concatenate(inputs, axis=self.axis)
#     File "c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\keras\backend.py", line 3313, in concatenate
#       return tf.concat([to_dense(x) for x in tensors], axis)
# Node: 'model/concatenate_3/concat'
# OOM when allocating tensor with shape[30,64,256,256] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node model/concatenate_3/concat}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_predict_function_55115]
