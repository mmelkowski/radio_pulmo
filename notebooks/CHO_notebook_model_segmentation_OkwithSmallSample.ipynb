# %%
#https://www.kaggle.com/code/nikhilpandey360/lung-segmentation-from-chest-x-ray-datasetb

# %%
import numpy as np 
import tensorflow as tf
import pandas as pd
#from tqdm import tqdm
import os
from cv2 import imread, createCLAHE 
import cv2
from glob import glob
# %matplotlib inline
import matplotlib.pyplot as plt


path_to_data = r"C:\Users\Inrae\Documents\Projet_Data_Science"
data_folder_path = os.path.join(path_to_data,"COVID-19_Radiography_Dataset")

cat="Normal"
image_path = os.path.join(data_folder_path,cat,"images")
mask_path = os.path.join(data_folder_path,cat,"masks")
# image_path = os.path.join("../input/data/Lung Segmentation/CXR_png")
# mask_path = os.path.join("../input/data/Lung Segmentation/","masks/")

# %%
# we have 704 masks but 800 images. Hence we are going to
# make a 1-1 correspondance from mask to images, not the usual other way.
images = os.listdir(image_path)
mask = os.listdir(mask_path)

# %%
#perform sanity check

def plotMask(X,y):
    sample = []
    
    for i in range(6):
        left = X[i]
        right = y[i]
        combined = np.hstack((left,right))
        sample.append(combined)
        
        
    for i in range(0,6,3):

        plt.figure(figsize=(25,10))
        
        plt.subplot(2,3,1+i)
        plt.imshow(sample[i])
        
        plt.subplot(2,3,2+i)
        plt.imshow(sample[i+1])
        
        
        plt.subplot(2,3,3+i)
        plt.imshow(sample[i+2])
        
        plt.show()

# %%
import random

testing_files = os.listdir(image_path)
val_samples = 2000
random.Random(1337).shuffle(testing_files)
testing_files = testing_files[:-val_samples]
training_files = testing_files[:-val_samples]

#testing_files = set(os.listdir(image_path)) & set(os.listdir(mask_path))
#training_files = check

def getData(X_shape, flag = "test"):
    im_array = []
    mask_array = []
    
    if flag == "test":
        for i in testing_files: 
            im = cv2.resize(cv2.imread(os.path.join(image_path,i)),(X_shape,X_shape))[:,:,0]
            mask = cv2.resize(cv2.imread(os.path.join(mask_path,i)),(X_shape,X_shape))[:,:,0]
            
            im_array.append(im)
            mask_array.append(mask)
        
        return im_array,mask_array
    
    if flag == "train":
        for i in training_files: 
            im = cv2.resize(cv2.imread(os.path.join(image_path,i)),(X_shape,X_shape))[:,:,0]
            mask = cv2.resize(cv2.imread(os.path.join(mask_path,i)),(X_shape,X_shape))[:,:,0]

            im_array.append(im)
            mask_array.append(mask)

        return im_array,mask_array

# %%
# Load training and testing data
dim = 256
X_train,y_train = getData(dim,flag="train")
X_test, y_test = getData(dim)

X_train = np.array(X_train).reshape(len(X_train),dim,dim,1)
y_train = np.array(y_train).reshape(len(y_train),dim,dim,1)
X_test = np.array(X_test).reshape(len(X_test),dim,dim,1)
y_test = np.array(y_test).reshape(len(y_test),dim,dim,1)
assert X_train.shape == y_train.shape
assert X_test.shape == y_test.shape
images = np.concatenate((X_train,X_test),axis=0)
mask  = np.concatenate((y_train,y_test),axis=0)

# %%
print("training set")
plotMask(X_train,y_train)
print("testing set")
plotMask(X_test,y_test)
# Out:
# training set
# testing set

# %%
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras import backend as keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler


def dice_coef(y_true, y_pred):
    y_true_f = keras.flatten(y_true)
    y_pred_f = keras.flatten(y_pred)
    intersection = keras.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (keras.sum(y_true_f) + keras.sum(y_pred_f) + 1)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def unet(input_size=(dim,dim,1)):
    inputs = Input(input_size)
    
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

    return Model(inputs=[inputs], outputs=[conv10])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
weight_path="{}_weights.best.hdf5".format('cxr_reg')

checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, 
                             save_best_only=True, mode='min', save_weights_only = True)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.5, 
                                   patience=3, 
                                   verbose=1, mode='min', min_delta=0.0001, cooldown=2, min_lr=1e-6)
early = EarlyStopping(monitor="val_loss", 
                      mode="min", 
                      patience=15) # probably needs to be more patient, but kaggle time is limited
callbacks_list = [checkpoint, early, reduceLROnPlat]

# %%
model = unet(input_size=(256,256,1))
model.compile(optimizer=Adam(lr=0.0001), loss=dice_coef_loss,
                  metrics=[dice_coef, 'binary_accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 32  320         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 32  9248        ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 32  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 64  18496       ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 64  36928       ['conv2d_2[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 64)  0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 128)  147584      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 128)  0          ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 256)  590080      ['conv2d_6[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 256)  0          ['conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 512)  1180160     ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 512)  2359808     ['conv2d_8[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 256)  524544     ['conv2d_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 32, 32, 512)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 256)  1179904     ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 256)  590080      ['conv2d_10[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 128)  131200     ['conv2d_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 256)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 128)  295040      ['concatenate_1[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 128)  147584      ['conv2d_12[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 64  32832      ['conv2d_13[0][0]']
#  spose)                         )
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_transpose_2[0][0]',
#                                 8)                                'conv2d_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 64  36928       ['conv2d_14[0][0]']
#                                 )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 32  8224       ['conv2d_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 64  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 32  18464       ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 256, 256, 32  9248        ['conv2d_16[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 1)  33          ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 7,759,521
# Trainable params: 7,759,521
# Non-trainable params: 0
# __________________________________________________________________________________________________
# c:\Users\Inrae\anaconda3\envs\tensor_env\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
#del loss_history
import gc
gc.collect()
tf.keras.backend.clear_session()


from IPython.display import clear_output
from tensorflow.keras.optimizers import Adam 
from sklearn.model_selection import train_test_split


train_vol, validation_vol, train_seg, validation_seg = train_test_split((images[:600]-127)/127, 
                                                             (mask[:600]>127).astype(np.float32),
                                                             test_size = 0.1,random_state = 2018)

train_vol, test_vol, train_seg, test_seg = train_test_split(train_vol,train_seg, 
                                                            test_size = 0.1, 
                                                            random_state = 2018)


loss_history = model.fit(x = train_vol,
                       y = train_seg,
                         batch_size = 8,
                  epochs = 100,
                  validation_data =(test_vol,test_seg) ,
                  callbacks=callbacks_list)
# Out:
# Epoch 1/100
# 61/61 [==============================] - ETA: 0s - loss: -0.3983 - dice_coef: 0.3984 - binary_accuracy: 0.2544
# Epoch 1: val_loss did not improve from -0.95581
# 61/61 [==============================] - 15s 230ms/step - loss: -0.3983 - dice_coef: 0.3984 - binary_accuracy: 0.2544 - val_loss: -0.4518 - val_dice_coef: 0.4529 - val_binary_accuracy: 0.2637 - lr: 1.0000e-04
# Epoch 2/100
# 61/61 [==============================] - ETA: 0s - loss: -0.6204 - dice_coef: 0.6210 - binary_accuracy: 0.6813
# Epoch 2: val_loss did not improve from -0.95581
# 61/61 [==============================] - 14s 222ms/step - loss: -0.6204 - dice_coef: 0.6210 - binary_accuracy: 0.6813 - val_loss: -0.7839 - val_dice_coef: 0.7843 - val_binary_accuracy: 0.8826 - lr: 1.0000e-04
# Epoch 3/100
# 61/61 [==============================] - ETA: 0s - loss: -0.8062 - dice_coef: 0.8061 - binary_accuracy: 0.9016
# Epoch 3: val_loss did not improve from -0.95581
# 61/61 [==============================] - 13s 214ms/step - loss: -0.8062 - dice_coef: 0.8061 - binary_accuracy: 0.9016 - val_loss: -0.8474 - val_dice_coef: 0.8478 - val_binary_accuracy: 0.9223 - lr: 1.0000e-04
# Epoch 4/100
# 61/61 [==============================] - ETA: 0s - loss: -0.8427 - dice_coef: 0.8428 - binary_accuracy: 0.9207
# Epoch 4: val_loss did not improve from -0.95581
# 61/61 [==============================] - 14s 222ms/step - loss: -0.8427 - dice_coef: 0.8428 - binary_accuracy: 0.9207 - val_loss: -0.8769 - val_dice_coef: 0.8770 - val_binary_accuracy: 0.9346 - lr: 1.0000e-04
# Epoch 5/100
# 61/61 [==============================] - ETA: 0s - loss: -0.8712 - dice_coef: 0.8712 - binary_accuracy: 0.9357
# Epoch 5: val_loss did not improve from -0.95581
# 61/61 [==============================] - 14s 225ms/step - loss: -0.8712 - dice_coef: 0.8712 - binary_accuracy: 0.9357 - val_loss: -0.8910 - val_dice_coef: 0.8913 - val_binary_accuracy: 0.9416 - lr: 1.0000e-04
# Epoch 6/100
# 61/61 [==============================] - ETA: 0s - loss: -0.8886 - dice_coef: 0.8887 - binary_accuracy: 0.9442
# Epoch 6: val_loss did not improve from -0.95581
# 61/61 [==============================] - 13s 220ms/step - loss: -0.8886 - dice_coef: 0.8887 - binary_accuracy: 0.9442 - val_loss: -0.8932 - val_dice_coef: 0.8934 - val_binary_accuracy: 0.9462 - lr: 1.0000e-04
# Epoch 7/100
# 61/61 [==============================] - ETA: 0s - loss: -0.8992 - dice_coef: 0.8991 - binary_accuracy: 0.9501
# Epoch 7: val_loss did not improve from -0.95581
# 61/61 [==============================] - 14s 222ms/step - loss: -0.8992 - dice_coef: 0.8991 - binary_accuracy: 0.9501 - val_loss: -0.9139 - val_dice_coef: 0.9143 - val_binary_accuracy: 0.9546 - lr: 1.0000e-04
# Epoch 8/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9168 - dice_coef: 0.9168 - binary_accuracy: 0.9587
# Epoch 8: val_loss did not improve from -0.95581
# 61/61 [==============================] - 13s 218ms/step - loss: -0.9168 - dice_coef: 0.9168 - binary_accuracy: 0.9587 - val_loss: -0.9189 - val_dice_coef: 0.9194 - val_binary_accuracy: 0.9565 - lr: 1.0000e-04
# Epoch 9/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9260 - dice_coef: 0.9258 - binary_accuracy: 0.9631
# Epoch 9: val_loss did not improve from -0.95581
# 61/61 [==============================] - 13s 221ms/step - loss: -0.9260 - dice_coef: 0.9258 - binary_accuracy: 0.9631 - val_loss: -0.9304 - val_dice_coef: 0.9308 - val_binary_accuracy: 0.9638 - lr: 1.0000e-04
# Epoch 10/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9347 - dice_coef: 0.9347 - binary_accuracy: 0.9674
# Epoch 10: val_loss did not improve from -0.95581
# 61/61 [==============================] - 13s 220ms/step - loss: -0.9347 - dice_coef: 0.9347 - binary_accuracy: 0.9674 - val_loss: -0.9337 - val_dice_coef: 0.9342 - val_binary_accuracy: 0.9648 - lr: 1.0000e-04
# Epoch 11/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9402 - dice_coef: 0.9403 - binary_accuracy: 0.9700
# Epoch 11: val_loss did not improve from -0.95581
# 61/61 [==============================] - 14s 223ms/step - loss: -0.9402 - dice_coef: 0.9403 - binary_accuracy: 0.9700 - val_loss: -0.9383 - val_dice_coef: 0.9387 - val_binary_accuracy: 0.9683 - lr: 1.0000e-04
# Epoch 12/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9456 - dice_coef: 0.9456 - binary_accuracy: 0.9727
# Epoch 12: val_loss did not improve from -0.95581
# 61/61 [==============================] - 14s 226ms/step - loss: -0.9456 - dice_coef: 0.9456 - binary_accuracy: 0.9727 - val_loss: -0.9429 - val_dice_coef: 0.9435 - val_binary_accuracy: 0.9696 - lr: 1.0000e-04
# Epoch 13/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9498 - dice_coef: 0.9498 - binary_accuracy: 0.9749
# Epoch 13: val_loss did not improve from -0.95581
# 61/61 [==============================] - 14s 224ms/step - loss: -0.9498 - dice_coef: 0.9498 - binary_accuracy: 0.9749 - val_loss: -0.9431 - val_dice_coef: 0.9437 - val_binary_accuracy: 0.9695 - lr: 1.0000e-04
# Epoch 14/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9519 - dice_coef: 0.9520 - binary_accuracy: 0.9759
# Epoch 14: val_loss did not improve from -0.95581
# 61/61 [==============================] - 14s 222ms/step - loss: -0.9519 - dice_coef: 0.9520 - binary_accuracy: 0.9759 - val_loss: -0.9472 - val_dice_coef: 0.9477 - val_binary_accuracy: 0.9724 - lr: 1.0000e-04
# Epoch 15/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9558 - dice_coef: 0.9557 - binary_accuracy: 0.9779
# Epoch 15: val_loss did not improve from -0.95581
# 61/61 [==============================] - 14s 226ms/step - loss: -0.9558 - dice_coef: 0.9557 - binary_accuracy: 0.9779 - val_loss: -0.9533 - val_dice_coef: 0.9538 - val_binary_accuracy: 0.9755 - lr: 1.0000e-04
# Epoch 16/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9596 - dice_coef: 0.9596 - binary_accuracy: 0.9797
# Epoch 16: val_loss did not improve from -0.95581
# 61/61 [==============================] - 14s 225ms/step - loss: -0.9596 - dice_coef: 0.9596 - binary_accuracy: 0.9797 - val_loss: -0.9510 - val_dice_coef: 0.9514 - val_binary_accuracy: 0.9749 - lr: 1.0000e-04
# Epoch 17/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9591 - dice_coef: 0.9591 - binary_accuracy: 0.9795
# Epoch 17: val_loss did not improve from -0.95581
# 61/61 [==============================] - 14s 228ms/step - loss: -0.9591 - dice_coef: 0.9591 - binary_accuracy: 0.9795 - val_loss: -0.9543 - val_dice_coef: 0.9548 - val_binary_accuracy: 0.9762 - lr: 1.0000e-04
# Epoch 18/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9629 - dice_coef: 0.9629 - binary_accuracy: 0.9814
# Epoch 18: val_loss improved from -0.95581 to -0.95883, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 228ms/step - loss: -0.9629 - dice_coef: 0.9629 - binary_accuracy: 0.9814 - val_loss: -0.9588 - val_dice_coef: 0.9593 - val_binary_accuracy: 0.9784 - lr: 1.0000e-04
# Epoch 19/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9647 - dice_coef: 0.9647 - binary_accuracy: 0.9824
# Epoch 19: val_loss did not improve from -0.95883
# 61/61 [==============================] - 14s 226ms/step - loss: -0.9647 - dice_coef: 0.9647 - binary_accuracy: 0.9824 - val_loss: -0.9581 - val_dice_coef: 0.9586 - val_binary_accuracy: 0.9779 - lr: 1.0000e-04
# Epoch 20/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9664 - dice_coef: 0.9664 - binary_accuracy: 0.9832
# Epoch 20: val_loss did not improve from -0.95883
# 61/61 [==============================] - 14s 227ms/step - loss: -0.9664 - dice_coef: 0.9664 - binary_accuracy: 0.9832 - val_loss: -0.9578 - val_dice_coef: 0.9583 - val_binary_accuracy: 0.9776 - lr: 1.0000e-04
# Epoch 21/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9674 - dice_coef: 0.9674 - binary_accuracy: 0.9837
# Epoch 21: val_loss improved from -0.95883 to -0.96175, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 15s 238ms/step - loss: -0.9674 - dice_coef: 0.9674 - binary_accuracy: 0.9837 - val_loss: -0.9617 - val_dice_coef: 0.9623 - val_binary_accuracy: 0.9799 - lr: 1.0000e-04
# Epoch 22/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9698 - dice_coef: 0.9698 - binary_accuracy: 0.9849
# Epoch 22: val_loss improved from -0.96175 to -0.96212, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 227ms/step - loss: -0.9698 - dice_coef: 0.9698 - binary_accuracy: 0.9849 - val_loss: -0.9621 - val_dice_coef: 0.9626 - val_binary_accuracy: 0.9802 - lr: 1.0000e-04
# Epoch 23/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9702 - dice_coef: 0.9701 - binary_accuracy: 0.9851
# Epoch 23: val_loss did not improve from -0.96212
# 61/61 [==============================] - 14s 226ms/step - loss: -0.9702 - dice_coef: 0.9701 - binary_accuracy: 0.9851 - val_loss: -0.9614 - val_dice_coef: 0.9618 - val_binary_accuracy: 0.9799 - lr: 1.0000e-04
# Epoch 24/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9710 - dice_coef: 0.9710 - binary_accuracy: 0.9855
# Epoch 24: val_loss improved from -0.96212 to -0.96352, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 222ms/step - loss: -0.9710 - dice_coef: 0.9710 - binary_accuracy: 0.9855 - val_loss: -0.9635 - val_dice_coef: 0.9639 - val_binary_accuracy: 0.9810 - lr: 1.0000e-04
# Epoch 25/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9734 - dice_coef: 0.9734 - binary_accuracy: 0.9867
# Epoch 25: val_loss did not improve from -0.96352
# 61/61 [==============================] - 13s 221ms/step - loss: -0.9734 - dice_coef: 0.9734 - binary_accuracy: 0.9867 - val_loss: -0.9628 - val_dice_coef: 0.9633 - val_binary_accuracy: 0.9804 - lr: 1.0000e-04
# Epoch 26/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9738 - dice_coef: 0.9738 - binary_accuracy: 0.9869
# Epoch 26: val_loss did not improve from -0.96352
# 61/61 [==============================] - 14s 224ms/step - loss: -0.9738 - dice_coef: 0.9738 - binary_accuracy: 0.9869 - val_loss: -0.9630 - val_dice_coef: 0.9635 - val_binary_accuracy: 0.9805 - lr: 1.0000e-04
# Epoch 27/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9730 - dice_coef: 0.9730 - binary_accuracy: 0.9865
# Epoch 27: val_loss improved from -0.96352 to -0.96466, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 232ms/step - loss: -0.9730 - dice_coef: 0.9730 - binary_accuracy: 0.9865 - val_loss: -0.9647 - val_dice_coef: 0.9651 - val_binary_accuracy: 0.9816 - lr: 1.0000e-04
# Epoch 28/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9744 - dice_coef: 0.9744 - binary_accuracy: 0.9872
# Epoch 28: val_loss did not improve from -0.96466
# 61/61 [==============================] - 14s 231ms/step - loss: -0.9744 - dice_coef: 0.9744 - binary_accuracy: 0.9872 - val_loss: -0.9634 - val_dice_coef: 0.9638 - val_binary_accuracy: 0.9807 - lr: 1.0000e-04
# Epoch 29/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9761 - dice_coef: 0.9761 - binary_accuracy: 0.9880
# Epoch 29: val_loss did not improve from -0.96466
# 61/61 [==============================] - 13s 217ms/step - loss: -0.9761 - dice_coef: 0.9761 - binary_accuracy: 0.9880 - val_loss: -0.9643 - val_dice_coef: 0.9649 - val_binary_accuracy: 0.9813 - lr: 1.0000e-04
# Epoch 30/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9766 - dice_coef: 0.9766 - binary_accuracy: 0.9883
# Epoch 30: val_loss improved from -0.96466 to -0.96578, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 223ms/step - loss: -0.9766 - dice_coef: 0.9766 - binary_accuracy: 0.9883 - val_loss: -0.9658 - val_dice_coef: 0.9662 - val_binary_accuracy: 0.9821 - lr: 1.0000e-04
# Epoch 31/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9772 - dice_coef: 0.9772 - binary_accuracy: 0.9886
# Epoch 31: val_loss improved from -0.96578 to -0.96732, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 13s 221ms/step - loss: -0.9772 - dice_coef: 0.9772 - binary_accuracy: 0.9886 - val_loss: -0.9673 - val_dice_coef: 0.9677 - val_binary_accuracy: 0.9830 - lr: 1.0000e-04
# Epoch 32/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9788 - dice_coef: 0.9788 - binary_accuracy: 0.9894
# Epoch 32: val_loss did not improve from -0.96732
# 61/61 [==============================] - 13s 221ms/step - loss: -0.9788 - dice_coef: 0.9788 - binary_accuracy: 0.9894 - val_loss: -0.9670 - val_dice_coef: 0.9675 - val_binary_accuracy: 0.9828 - lr: 1.0000e-04
# Epoch 33/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9788 - dice_coef: 0.9788 - binary_accuracy: 0.9894
# Epoch 33: val_loss did not improve from -0.96732
# 61/61 [==============================] - 13s 218ms/step - loss: -0.9788 - dice_coef: 0.9788 - binary_accuracy: 0.9894 - val_loss: -0.9654 - val_dice_coef: 0.9658 - val_binary_accuracy: 0.9818 - lr: 1.0000e-04
# Epoch 34/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9788 - dice_coef: 0.9789 - binary_accuracy: 0.9894
# Epoch 34: val_loss improved from -0.96732 to -0.96872, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 13s 220ms/step - loss: -0.9788 - dice_coef: 0.9789 - binary_accuracy: 0.9894 - val_loss: -0.9687 - val_dice_coef: 0.9691 - val_binary_accuracy: 0.9837 - lr: 1.0000e-04
# Epoch 35/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9799 - dice_coef: 0.9799 - binary_accuracy: 0.9899
# Epoch 35: val_loss did not improve from -0.96872
# 61/61 [==============================] - 13s 219ms/step - loss: -0.9799 - dice_coef: 0.9799 - binary_accuracy: 0.9899 - val_loss: -0.9675 - val_dice_coef: 0.9679 - val_binary_accuracy: 0.9830 - lr: 1.0000e-04
# Epoch 36/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9810 - dice_coef: 0.9810 - binary_accuracy: 0.9905
# Epoch 36: val_loss improved from -0.96872 to -0.96927, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 13s 221ms/step - loss: -0.9810 - dice_coef: 0.9810 - binary_accuracy: 0.9905 - val_loss: -0.9693 - val_dice_coef: 0.9696 - val_binary_accuracy: 0.9840 - lr: 1.0000e-04
# Epoch 37/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9809 - dice_coef: 0.9809 - binary_accuracy: 0.9904
# Epoch 37: val_loss improved from -0.96927 to -0.96946, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 13s 221ms/step - loss: -0.9809 - dice_coef: 0.9809 - binary_accuracy: 0.9904 - val_loss: -0.9695 - val_dice_coef: 0.9698 - val_binary_accuracy: 0.9840 - lr: 1.0000e-04
# Epoch 38/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9821 - dice_coef: 0.9821 - binary_accuracy: 0.9910
# Epoch 38: val_loss improved from -0.96946 to -0.97128, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 223ms/step - loss: -0.9821 - dice_coef: 0.9821 - binary_accuracy: 0.9910 - val_loss: -0.9713 - val_dice_coef: 0.9716 - val_binary_accuracy: 0.9850 - lr: 1.0000e-04
# Epoch 39/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9809 - dice_coef: 0.9809 - binary_accuracy: 0.9905
# Epoch 39: val_loss did not improve from -0.97128
# 61/61 [==============================] - 13s 220ms/step - loss: -0.9809 - dice_coef: 0.9809 - binary_accuracy: 0.9905 - val_loss: -0.9703 - val_dice_coef: 0.9707 - val_binary_accuracy: 0.9845 - lr: 1.0000e-04
# Epoch 40/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9821 - dice_coef: 0.9821 - binary_accuracy: 0.9910
# Epoch 40: val_loss did not improve from -0.97128
# 61/61 [==============================] - 13s 218ms/step - loss: -0.9821 - dice_coef: 0.9821 - binary_accuracy: 0.9910 - val_loss: -0.9698 - val_dice_coef: 0.9702 - val_binary_accuracy: 0.9843 - lr: 1.0000e-04
# Epoch 41/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9836 - dice_coef: 0.9836 - binary_accuracy: 0.9918
# Epoch 41: val_loss did not improve from -0.97128
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 61/61 [==============================] - 13s 218ms/step - loss: -0.9836 - dice_coef: 0.9836 - binary_accuracy: 0.9918 - val_loss: -0.9674 - val_dice_coef: 0.9678 - val_binary_accuracy: 0.9827 - lr: 1.0000e-04
# Epoch 42/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9850 - dice_coef: 0.9850 - binary_accuracy: 0.9925
# Epoch 42: val_loss improved from -0.97128 to -0.97188, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 13s 219ms/step - loss: -0.9850 - dice_coef: 0.9850 - binary_accuracy: 0.9925 - val_loss: -0.9719 - val_dice_coef: 0.9722 - val_binary_accuracy: 0.9853 - lr: 5.0000e-05
# Epoch 43/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9862 - dice_coef: 0.9862 - binary_accuracy: 0.9931
# Epoch 43: val_loss did not improve from -0.97188
# 61/61 [==============================] - 13s 219ms/step - loss: -0.9862 - dice_coef: 0.9862 - binary_accuracy: 0.9931 - val_loss: -0.9716 - val_dice_coef: 0.9720 - val_binary_accuracy: 0.9852 - lr: 5.0000e-05
# Epoch 44/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9865 - dice_coef: 0.9866 - binary_accuracy: 0.9933
# Epoch 44: val_loss improved from -0.97188 to -0.97246, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 224ms/step - loss: -0.9865 - dice_coef: 0.9866 - binary_accuracy: 0.9933 - val_loss: -0.9725 - val_dice_coef: 0.9728 - val_binary_accuracy: 0.9856 - lr: 5.0000e-05
# Epoch 45/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9862 - dice_coef: 0.9863 - binary_accuracy: 0.9931
# Epoch 45: val_loss did not improve from -0.97246
# 61/61 [==============================] - 14s 226ms/step - loss: -0.9862 - dice_coef: 0.9863 - binary_accuracy: 0.9931 - val_loss: -0.9723 - val_dice_coef: 0.9726 - val_binary_accuracy: 0.9855 - lr: 5.0000e-05
# Epoch 46/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9867 - dice_coef: 0.9867 - binary_accuracy: 0.9934
# Epoch 46: val_loss did not improve from -0.97246
# 61/61 [==============================] - 14s 222ms/step - loss: -0.9867 - dice_coef: 0.9867 - binary_accuracy: 0.9934 - val_loss: -0.9723 - val_dice_coef: 0.9726 - val_binary_accuracy: 0.9855 - lr: 5.0000e-05
# Epoch 47/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9873 - dice_coef: 0.9873 - binary_accuracy: 0.9937
# Epoch 47: val_loss improved from -0.97246 to -0.97315, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 223ms/step - loss: -0.9873 - dice_coef: 0.9873 - binary_accuracy: 0.9937 - val_loss: -0.9732 - val_dice_coef: 0.9735 - val_binary_accuracy: 0.9860 - lr: 5.0000e-05
# Epoch 48/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9876 - dice_coef: 0.9876 - binary_accuracy: 0.9938
# Epoch 48: val_loss did not improve from -0.97315
# 61/61 [==============================] - 13s 220ms/step - loss: -0.9876 - dice_coef: 0.9876 - binary_accuracy: 0.9938 - val_loss: -0.9726 - val_dice_coef: 0.9730 - val_binary_accuracy: 0.9857 - lr: 5.0000e-05
# Epoch 49/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9876 - dice_coef: 0.9876 - binary_accuracy: 0.9938
# Epoch 49: val_loss did not improve from -0.97315
# 61/61 [==============================] - 13s 219ms/step - loss: -0.9876 - dice_coef: 0.9876 - binary_accuracy: 0.9938 - val_loss: -0.9726 - val_dice_coef: 0.9730 - val_binary_accuracy: 0.9857 - lr: 5.0000e-05
# Epoch 50/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9879 - dice_coef: 0.9879 - binary_accuracy: 0.9940
# Epoch 50: val_loss did not improve from -0.97315
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 61/61 [==============================] - 13s 221ms/step - loss: -0.9879 - dice_coef: 0.9879 - binary_accuracy: 0.9940 - val_loss: -0.9726 - val_dice_coef: 0.9730 - val_binary_accuracy: 0.9856 - lr: 5.0000e-05
# Epoch 51/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9890 - dice_coef: 0.9890 - binary_accuracy: 0.9945
# Epoch 51: val_loss improved from -0.97315 to -0.97350, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 14s 222ms/step - loss: -0.9890 - dice_coef: 0.9890 - binary_accuracy: 0.9945 - val_loss: -0.9735 - val_dice_coef: 0.9738 - val_binary_accuracy: 0.9862 - lr: 2.5000e-05
# Epoch 52/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9895 - dice_coef: 0.9895 - binary_accuracy: 0.9948
# Epoch 52: val_loss did not improve from -0.97350
# 61/61 [==============================] - 14s 225ms/step - loss: -0.9895 - dice_coef: 0.9895 - binary_accuracy: 0.9948 - val_loss: -0.9734 - val_dice_coef: 0.9737 - val_binary_accuracy: 0.9861 - lr: 2.5000e-05
# Epoch 53/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9897 - dice_coef: 0.9897 - binary_accuracy: 0.9949
# Epoch 53: val_loss did not improve from -0.97350
# 61/61 [==============================] - 13s 221ms/step - loss: -0.9897 - dice_coef: 0.9897 - binary_accuracy: 0.9949 - val_loss: -0.9733 - val_dice_coef: 0.9736 - val_binary_accuracy: 0.9860 - lr: 2.5000e-05
# Epoch 54/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9896 - dice_coef: 0.9896 - binary_accuracy: 0.9948
# Epoch 54: val_loss did not improve from -0.97350
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 61/61 [==============================] - 13s 218ms/step - loss: -0.9896 - dice_coef: 0.9896 - binary_accuracy: 0.9948 - val_loss: -0.9730 - val_dice_coef: 0.9733 - val_binary_accuracy: 0.9859 - lr: 2.5000e-05
# Epoch 55/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9902 - dice_coef: 0.9902 - binary_accuracy: 0.9951
# Epoch 55: val_loss did not improve from -0.97350
# 61/61 [==============================] - 13s 219ms/step - loss: -0.9902 - dice_coef: 0.9902 - binary_accuracy: 0.9951 - val_loss: -0.9734 - val_dice_coef: 0.9738 - val_binary_accuracy: 0.9861 - lr: 1.2500e-05
# Epoch 56/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9906 - dice_coef: 0.9906 - binary_accuracy: 0.9953
# Epoch 56: val_loss improved from -0.97350 to -0.97361, saving model to cxr_reg_weights.best.hdf5
# 61/61 [==============================] - 13s 221ms/step - loss: -0.9906 - dice_coef: 0.9906 - binary_accuracy: 0.9953 - val_loss: -0.9736 - val_dice_coef: 0.9740 - val_binary_accuracy: 0.9862 - lr: 1.2500e-05
# Epoch 57/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9905 - dice_coef: 0.9906 - binary_accuracy: 0.9953
# Epoch 57: val_loss did not improve from -0.97361
# 61/61 [==============================] - 14s 227ms/step - loss: -0.9905 - dice_coef: 0.9906 - binary_accuracy: 0.9953 - val_loss: -0.9734 - val_dice_coef: 0.9738 - val_binary_accuracy: 0.9861 - lr: 1.2500e-05
# Epoch 58/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9908 - dice_coef: 0.9908 - binary_accuracy: 0.9954
# Epoch 58: val_loss did not improve from -0.97361
# 61/61 [==============================] - 13s 220ms/step - loss: -0.9908 - dice_coef: 0.9908 - binary_accuracy: 0.9954 - val_loss: -0.9735 - val_dice_coef: 0.9739 - val_binary_accuracy: 0.9862 - lr: 1.2500e-05
# Epoch 59/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9909 - dice_coef: 0.9909 - binary_accuracy: 0.9955
# Epoch 59: val_loss improved from -0.97361 to -0.97367, saving model to cxr_reg_weights.best.hdf5
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 61/61 [==============================] - 13s 221ms/step - loss: -0.9909 - dice_coef: 0.9909 - binary_accuracy: 0.9955 - val_loss: -0.9737 - val_dice_coef: 0.9740 - val_binary_accuracy: 0.9862 - lr: 1.2500e-05
# Epoch 60/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9911 - dice_coef: 0.9911 - binary_accuracy: 0.9956
# Epoch 60: val_loss did not improve from -0.97367
# 61/61 [==============================] - 14s 229ms/step - loss: -0.9911 - dice_coef: 0.9911 - binary_accuracy: 0.9956 - val_loss: -0.9735 - val_dice_coef: 0.9739 - val_binary_accuracy: 0.9862 - lr: 6.2500e-06
# Epoch 61/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9913 - dice_coef: 0.9913 - binary_accuracy: 0.9957
# Epoch 61: val_loss did not improve from -0.97367
# 61/61 [==============================] - 13s 219ms/step - loss: -0.9913 - dice_coef: 0.9913 - binary_accuracy: 0.9957 - val_loss: -0.9735 - val_dice_coef: 0.9739 - val_binary_accuracy: 0.9862 - lr: 6.2500e-06
# Epoch 62/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9914 - dice_coef: 0.9914 - binary_accuracy: 0.9957
# Epoch 62: val_loss did not improve from -0.97367
# 61/61 [==============================] - 13s 218ms/step - loss: -0.9914 - dice_coef: 0.9914 - binary_accuracy: 0.9957 - val_loss: -0.9736 - val_dice_coef: 0.9739 - val_binary_accuracy: 0.9862 - lr: 6.2500e-06
# Epoch 63/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9914 - dice_coef: 0.9914 - binary_accuracy: 0.9957
# Epoch 63: val_loss did not improve from -0.97367
#
# Epoch 63: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 61/61 [==============================] - 13s 221ms/step - loss: -0.9914 - dice_coef: 0.9914 - binary_accuracy: 0.9957 - val_loss: -0.9735 - val_dice_coef: 0.9739 - val_binary_accuracy: 0.9862 - lr: 6.2500e-06
# Epoch 64/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9915 - dice_coef: 0.9915 - binary_accuracy: 0.9958
# Epoch 64: val_loss did not improve from -0.97367
# 61/61 [==============================] - 13s 220ms/step - loss: -0.9915 - dice_coef: 0.9915 - binary_accuracy: 0.9958 - val_loss: -0.9736 - val_dice_coef: 0.9739 - val_binary_accuracy: 0.9862 - lr: 3.1250e-06
# Epoch 65/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9916 - dice_coef: 0.9916 - binary_accuracy: 0.9958
# Epoch 65: val_loss did not improve from -0.97367
# 61/61 [==============================] - 13s 220ms/step - loss: -0.9916 - dice_coef: 0.9916 - binary_accuracy: 0.9958 - val_loss: -0.9735 - val_dice_coef: 0.9739 - val_binary_accuracy: 0.9862 - lr: 3.1250e-06
# Epoch 66/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9916 - dice_coef: 0.9916 - binary_accuracy: 0.9959
# Epoch 66: val_loss did not improve from -0.97367
# 61/61 [==============================] - 14s 222ms/step - loss: -0.9916 - dice_coef: 0.9916 - binary_accuracy: 0.9959 - val_loss: -0.9735 - val_dice_coef: 0.9739 - val_binary_accuracy: 0.9862 - lr: 3.1250e-06
# Epoch 67/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9916 - dice_coef: 0.9916 - binary_accuracy: 0.9959
# Epoch 67: val_loss did not improve from -0.97367
#
# Epoch 67: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 61/61 [==============================] - 14s 224ms/step - loss: -0.9916 - dice_coef: 0.9916 - binary_accuracy: 0.9959 - val_loss: -0.9736 - val_dice_coef: 0.9740 - val_binary_accuracy: 0.9862 - lr: 3.1250e-06
# Epoch 68/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9917 - dice_coef: 0.9917 - binary_accuracy: 0.9959
# Epoch 68: val_loss did not improve from -0.97367
# 61/61 [==============================] - 13s 221ms/step - loss: -0.9917 - dice_coef: 0.9917 - binary_accuracy: 0.9959 - val_loss: -0.9736 - val_dice_coef: 0.9739 - val_binary_accuracy: 0.9862 - lr: 1.5625e-06
# Epoch 69/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9917 - dice_coef: 0.9917 - binary_accuracy: 0.9959
# Epoch 69: val_loss did not improve from -0.97367
# 61/61 [==============================] - 13s 220ms/step - loss: -0.9917 - dice_coef: 0.9917 - binary_accuracy: 0.9959 - val_loss: -0.9735 - val_dice_coef: 0.9739 - val_binary_accuracy: 0.9861 - lr: 1.5625e-06
# Epoch 70/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9918 - dice_coef: 0.9918 - binary_accuracy: 0.9959
# Epoch 70: val_loss did not improve from -0.97367
# 61/61 [==============================] - 14s 222ms/step - loss: -0.9918 - dice_coef: 0.9918 - binary_accuracy: 0.9959 - val_loss: -0.9736 - val_dice_coef: 0.9739 - val_binary_accuracy: 0.9862 - lr: 1.5625e-06
# Epoch 71/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9918 - dice_coef: 0.9918 - binary_accuracy: 0.9960
# Epoch 71: val_loss did not improve from -0.97367
#
# Epoch 71: ReduceLROnPlateau reducing learning rate to 1e-06.
# 61/61 [==============================] - 13s 221ms/step - loss: -0.9918 - dice_coef: 0.9918 - binary_accuracy: 0.9960 - val_loss: -0.9736 - val_dice_coef: 0.9739 - val_binary_accuracy: 0.9862 - lr: 1.5625e-06
# Epoch 72/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9918 - dice_coef: 0.9918 - binary_accuracy: 0.9960
# Epoch 72: val_loss did not improve from -0.97367
# 61/61 [==============================] - 13s 221ms/step - loss: -0.9918 - dice_coef: 0.9918 - binary_accuracy: 0.9960 - val_loss: -0.9736 - val_dice_coef: 0.9739 - val_binary_accuracy: 0.9862 - lr: 1.0000e-06
# Epoch 73/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9918 - dice_coef: 0.9918 - binary_accuracy: 0.9960
# Epoch 73: val_loss did not improve from -0.97367
# 61/61 [==============================] - 14s 224ms/step - loss: -0.9918 - dice_coef: 0.9918 - binary_accuracy: 0.9960 - val_loss: -0.9736 - val_dice_coef: 0.9739 - val_binary_accuracy: 0.9862 - lr: 1.0000e-06
# Epoch 74/100
# 61/61 [==============================] - ETA: 0s - loss: -0.9918 - dice_coef: 0.9918 - binary_accuracy: 0.9960
# Epoch 74: val_loss did not improve from -0.97367
# 61/61 [==============================] - 14s 229ms/step - loss: -0.9918 - dice_coef: 0.9918 - binary_accuracy: 0.9960 - val_loss: -0.9735 - val_dice_coef: 0.9739 - val_binary_accuracy: 0.9862 - lr: 1.0000e-06

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (10, 5))
ax1.plot(loss_history.history['loss'], '-', label = 'Loss')
ax1.plot(loss_history.history['val_loss'], '-', label = 'Validation Loss')
ax1.legend()

ax2.plot(100*np.array(loss_history.history['binary_accuracy']), '-', 
         label = 'Accuracy')
ax2.plot(100*np.array(loss_history.history['val_binary_accuracy']), '-',
         label = 'Validation Accuracy')
ax2.legend()

# %%
validation_vol_small = validation_vol[20:30]
validation_seg_small = validation_seg[20:30]

pred_candidates = np.random.randint(1,validation_vol_small.shape[0],10)
preds = model.predict(validation_vol_small)

plt.figure(figsize=(20,10))

for i in range(0,9,3):
    plt.subplot(3,3,i+1)
    
    plt.imshow(np.squeeze(validation_vol_small[pred_candidates[i]]))
    plt.xlabel("Base Image")
    
    
    plt.subplot(3,3,i+2)
    plt.imshow(np.squeeze(validation_seg_small[pred_candidates[i]]))
    plt.xlabel("Mask")
    
    plt.subplot(3,3,i+3)
    plt.imshow(np.squeeze(preds[pred_candidates[i]]))
    plt.xlabel("Prediction")
